# %%
import shap

explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values[1], X_test)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-895588876.py in <cell line: 0>()
#       4 shap_values = explainer.shap_values(X_test)
#       5
# ----> 6 shap.summary_plot(shap_values[1], X_test)
#
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     662             )
#     663         else:
# --> 664             assert num_features == features.shape[1], shape_msg
#     665
#     666     if feature_names is None:
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
rf_probs = rf.predict_proba(X_test)[:,1]
rf_pred = (rf_probs > 0.5).astype(int)

fp = X_test[(rf_pred==1) & (y_test==0)]
fn = X_test[(rf_pred==0) & (y_test==1)]

print("False Positives:", fp.shape)
print("False Negatives:", fn.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-927920598.py in <cell line: 0>()
# ----> 1 rf_probs = rf.predict_proba(X_test)[:,1]
#       2 rf_pred = (rf_probs > 0.5).astype(int)
#       3
#       4 fp = X_test[(rf_pred==1) & (y_test==0)]
#       5 fn = X_test[(rf_pred==0) & (y_test==1)]
#
# NameError: name 'rf' is not defined
